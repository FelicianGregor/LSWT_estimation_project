# %% [markdown]
# # Description
#
# This script allows to download a single variable data from the CCI
# dataset for a single lake according to user defined period.
# The zone will be defined by de boundaries of the polygon defining the lake.
# If there are other lakes near the specified one, they will be masked.
# This script is useful for dowloading data o fa single variable for a single
# lake. Information about its boundaries is not required.
#
#
# INPUT:
#     <ul>
#     <li>The identifier of the lake. The id of the lake is indicated
#       in the csv file containing lake metadata. This file is available
#       at the project website:
#         https://climate.esa.int/documents/2528/lakescci_v2.1_metadata.csv</li>
#     <li>Name of the variable in the netCDF files</li>
#     <li>Land mask: the netCDF file containing the mask of the lakes in CCI dataset this file
#       is part of the dataset and is available at:
#       https://dap.ceda.ac.uk/neodc/esacci/lakes/data/lake_products/L3S/v2.0.1/ESA_CCI_static_lake_mask_v2.0.1.nc</li>
#     <li>first/last date</li>
#     <li>version of the dataset to be download (default value 2.1.0)</li>
#     <li>ouptput dir to storage the extracted data</li>
#     <li>prefix (optional): to be added at the output files name</li>
#     </ul>
#
#  Reference: Carrea, L.; Crétaux, J.-F.; Liu, X.; Wu, Y.; Bergé-Nguyen,
#  M.; Calmettes, B.; Duguay, C.; Jiang, D.; Merchant, C.J.; Mueller, D.;
#  Selmes, N.; Simis, S.; Spyrakos, E.; Stelzer, K.; Warren, M.; Yesou,
#  H.; Zhang, D. (2022): ESA Lakes Climate Change Initiative (Lakes_cci):
#  Lake products, Version 2.1.0. NERC EDS Centre for Environmental Data
#  Analysis, date of citation.
#  https://dx.doi.org/10.5285/7fc9df8070d34cacab8092e45ef276f1
#
#
#  WARNING: This script is a beta version. All controls on the input parameters
#  are not (yet) available. If you find a bug, have a question or a
#  suggestion, don't hesitate to contact us, it will be much appreciated :
#  cci_lakes.contact@groupcls.com
#
#  to be executed with python version >= 3.9

# %% [markdown]
# # key variables
#
# Lakes_cci dataset is a merged product containing multiple variables from different thematic ECVs. The key variables are as follow:
#
# <b>Lake Water Level (LWL):</b>
# <ul><li>water_surface_height_above_reference_datum</li></ul>
#
# <b>Lake Water Extent (LWE):</b>
# <ul><li>lake_surface_water_extent</li></ul>
#
# <b>Lake Ice Cover (LIC):</b>
# <ul><li>lake_ice_cover_class</li></ul>
#
#
# <b>Lake Water Extent (LWE):</b>
# <ul><li>lake_surface_water_temperature</li></ul>
#
#
# <b>Lake Water Leaving Reflectance (LWLR):</b>
# <ul><li>chla_mean</li>
# <li>turbidity_mean</li>
# <li>Rwxxx with xxx: 400, 412, 443, 469, 490, 510, 531, 547, 560, 620, 645, 665, 674, 681, 709, 754, 779, 859, Rw885, 900, 1020</li></ul>

# %%
import os
import numpy as np
import xarray as xr
import datetime
import matplotlib.pyplot as plt
import pydap
#%matplotlib widget
#%matplotlib inline

# %% [markdown]
# # Step 1: Define input parameters.
#
# In this exemple, we download Lakes surface water temperature over Lake Victoria, one of the African Great Lakes.
#
# The lake identifier (3) was obtained from the csv file (https://climate.esa.int/documents/2607/lakescci_v2.1.0_metadata.csv) available in the project website: (https://climate.esa.int/fr/projects/lakes/)
#
# In our case, we are interesteb by data in 2022

# %%
###########################################################################################
# input parameters
###########################################################################################   

# lakes mask file 
maskfile = 'ESA_CCI_static_lake_mask_v2.1.nc'

# Id for lake Kangaarsuup Tasersua
lake_id = 300003969

# variable name
varname = 'lake_surface_water_temperature'

# defining the period of time in string format: YYYY-MM-DD
# dates values must be between 1992-09-26 and 2020-12-31
mindate = '2022-01-01'
maxdate = '2022-12-31'

# version dataset (2.1.0 is the version published in April 2024)
version = '3.0'

# output
outdir = 'output/Kangaarsuup_Tasersua'
outprefix = 'lake6_lswt_'

# %%
# test if dates are in the temporal coverage

mindate = datetime.datetime.strptime(mindate, '%Y-%m-%d')
maxdate = datetime.datetime.strptime(maxdate, '%Y-%m-%d')
mindate = max([mindate, datetime.datetime(1992,9,26)])
maxdate = min([maxdate, datetime.datetime(2022,12,31)])

# %%
# create the output directory if it does not exist
if os.path.exists(outdir)==False:
    os.makedirs(outdir)

# %% [markdown]
# # Step 2: Mask creation
#
# In this step, latitude and longitude values inside the lake are obtained from the lake mask file. The boundary values will then be used to read the data in the region covering the lake.

# %%
###################################################################
# create mask based on lake_id
###################################################################

mask_xr = xr.open_dataset(maskfile)
mask = mask_xr['CCI_lakeid'].values
mask_ind  = np.where(mask == lake_id)
minx = np.min(mask_ind[1][:]) - 1
maxx = np.max(mask_ind[1][:]) + 1
miny = np.min(mask_ind[0][:]) - 1
maxy = np.max(mask_ind[0][:]) + 1

mask_lake = mask[miny:maxy+1, minx:maxx+1]
mask_lake[mask_lake!=lake_id] = 0
mask_lake[mask_lake == lake_id] = 1

lat = mask_xr['lat'][miny:maxy+1].values
lon = mask_xr['lon'][minx:maxx+1].values

# %% [markdown]
# A good validation test is to check that the lake ID is correct by visualising the lake mask.

# %%
# plot lake mask 
plt.matshow(mask_lake, extent=[np.min(lon), np.max(lon), np.min(lat), np.max(lat)])
plt.show()

# %% [markdown]
# # Step 3: Data download
#
# In this step, the data for the defined lake and variable is downloaded from each daily file and written, in netCDF format, to the output directory

# %%
#### The download process

for data_date in np.arange(mindate.toordinal(), maxdate.toordinal()+1):
    current_date = datetime.datetime.fromordinal(data_date)
    date_str = current_date.strftime("%Y%m%d")
    #print (f'Downloading data from lake_id {lake_id} -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-{date_str}-fv{version}.nc')
    print(f"\nDate is of tyep: {type(date_str)}")
    path  = f'https://data.cci.ceda.ac.uk/thredds/dodsC/esacci/lakes/data/lake_products/L3S/v2.1/merged_product/'
    path += f'/{current_date.year}/{current_date.month:02}/'
    path += f'ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-{date_str}-fv2.1.0.nc?{varname}[0:1:0][{miny}:1:{maxy}][{minx}:1:{maxx}]'
   
    # here: open the dataset from the path, using the netcdf4 engine, a different one compared to the script that has been downloaded from git (there it was "pydap", which had difficulties with the dictionaries)
    dataset = xr.open_dataset(path, engine="netcdf4")

    filval = dataset[varname].encoding['_FillValue']
    data = dataset[varname][0, :, :].values

    data[mask_lake == 0] = filval
    dataset[varname][0, :, :] = data

    outfile = f'{outdir}/{outprefix}ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-{date_str}-fv{version}.nc'

    dataset.to_netcdf(outfile)
# Out:
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220101-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220102-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220103-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220104-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220105-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220106-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220107-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220108-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220109-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220110-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220111-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220112-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220113-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220114-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220115-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220116-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220117-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220118-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220119-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220120-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220121-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220122-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220123-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220124-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220125-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220126-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220127-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220128-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220129-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220130-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220131-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220201-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220202-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220203-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220204-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220205-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220206-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220207-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220208-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220209-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220210-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220211-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220212-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220213-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220214-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220215-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220216-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220217-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220218-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220219-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220220-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220221-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220222-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220223-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220224-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220225-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220226-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220227-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220228-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220301-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220302-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220303-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220304-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220305-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220306-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220307-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220308-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220309-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220310-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220311-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220312-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220313-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220314-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220315-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220316-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220317-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220318-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220319-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220320-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220321-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220322-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220323-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220324-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220325-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220326-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220327-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220328-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220329-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220330-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220331-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220401-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220402-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220403-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220404-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220405-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220406-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220407-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220408-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220409-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220410-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220411-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220412-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220413-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220414-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220415-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220416-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220417-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220418-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220419-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220420-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220421-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220422-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220423-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220424-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220425-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220426-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220427-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220428-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220429-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220430-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220501-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220502-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220503-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220504-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220505-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220506-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220507-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220508-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220509-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220510-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220511-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220512-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220513-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220514-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220515-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220516-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220517-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220518-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220519-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220520-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220521-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220522-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220523-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220524-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220525-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220526-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220527-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220528-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220529-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220530-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220531-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220601-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220602-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220603-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220604-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220605-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220606-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220607-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220608-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220609-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220610-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220611-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220612-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220613-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220614-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220615-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220616-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220617-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220618-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220619-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220620-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220621-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220622-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220623-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220624-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220625-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220626-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220627-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220628-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220629-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220630-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220701-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220702-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220703-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220704-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220705-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220706-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220707-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220708-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220709-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220710-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220711-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220712-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220713-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220714-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220715-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220716-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220717-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220718-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220719-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220720-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220721-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220722-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220723-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220724-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220725-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220726-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220727-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220728-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220729-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220730-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220731-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220801-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220802-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220803-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220804-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220805-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220806-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220807-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220808-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220809-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220810-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220811-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220812-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220813-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220814-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220815-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220816-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220817-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220818-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220819-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220820-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220821-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220822-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220823-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220824-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220825-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220826-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220827-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220828-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220829-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220830-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220831-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220901-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220902-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220903-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220904-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220905-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220906-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220907-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220908-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220909-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220910-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220911-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220912-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220913-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220914-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220915-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220916-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220917-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220918-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220919-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220920-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220921-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220922-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220923-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220924-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220925-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220926-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220927-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220928-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220929-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220930-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20221001-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20221002-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20221003-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20221004-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20221005-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20221006-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20221007-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20221008-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20221009-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20221010-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20221011-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20221012-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20221013-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20221014-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20221015-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20221016-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20221017-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20221018-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20221019-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20221020-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20221021-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20221022-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20221023-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20221024-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20221025-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20221026-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20221027-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20221028-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20221029-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20221030-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20221031-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20221101-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20221102-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20221103-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20221104-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20221105-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20221106-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20221107-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20221108-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20221109-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20221110-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20221111-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20221112-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20221113-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20221114-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20221115-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20221116-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20221117-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20221118-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20221119-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20221120-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20221121-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20221122-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20221123-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20221124-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20221125-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20221126-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20221127-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20221128-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20221129-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20221130-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20221201-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20221202-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20221203-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20221204-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20221205-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20221206-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20221207-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20221208-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20221209-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20221210-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20221211-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20221212-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20221213-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20221214-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20221215-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20221216-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20221217-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20221218-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20221219-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20221220-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20221221-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20221222-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20221223-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20221224-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20221225-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20221226-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20221227-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20221228-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20221229-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20221230-fv3.0.nc
#
# Date is of tyep: <class 'str'>
# Downloading data from lake_id 300003969 -  ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20221231-fv3.0.nc
#
# Date is of tyep: <class 'str'>

# %% [markdown]
# ## read the `netcdf` files, inspect and combine to an xarray

# %%
# import modules
import netCDF4 # needed to read netcdf files backend by xarray
import xarray
import matplotlib.pyplot as plt

# %%
# 1. Open the NetCDF file
file_path = "output/Kangaarsuup_Tasersua/lake6_lswt_ESACCI-LAKES-L3S-LK_PRODUCTS-MERGED-20220821-fv3.0.nc"
dataset = xr.open_dataset(file_path)

# %%
dataset.coords
# Out:
# Coordinates:
#     *empty*

# %%
# 3. Extract your variable of interest (e.g., 'temperature' or 'sst')
# If your data has a 'time' dimension, select a specific index (e.g., first time step)
# replacing 'temperature' with the actual variable name found in step 2.
data_slice = dataset['lake_surface_water_temperature'].isel(time=0)

# 4. Plot the 2D spatial slice
data_slice.plot(cmap='viridis')
plt.show()
